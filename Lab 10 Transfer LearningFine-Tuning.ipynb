# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab10.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 10: Transfer Learning/Fine-Tuning

# %% [markdown]
# ## Description

# %% [markdown]
# ### Objective
#
# - Gain experience fine-tuning pre-trained models to domain-specific applications.
#
# ### Deliverable
#
# For this lab you will submit an IPython notebook via Learning Suite. The bulk of the work is in modifying fine-tuning a pre-trained ResNet. Fine-tuning the GPT-2 language model is pretty easy. The provided code works as is; you will just have to swap in your own text dataset.
#
# ### Grading
#
# - 35% Create a dataset class for your own dataset
# - 35% Create a network class that wraps a pretrained ResNet
# - 20% Implement unfreezing in the network class
# - 10% Fine-tune GPT-2 on your own dataset
#
# ### Tips
# - Your life will be better if you download a dataset that already has the data in the expected format for ImageFolder (make sure to read the documentation!). The datasets recommended below are in the correct format.
# - Get the CNN working on the provided dataset (bird species classification) before swapping in your own.
# - For reference on freezing/unfreezing network weights, see [this github gist](https://gist.github.com/jcjohnson/6e41e8512c17eae5da50aebef3378a4c)
# - Check PyTorch's documentation to learn the difference between `requires_grad=False` and `requires_grad_(False)`.
# - For training GPT-2, first try the medium-size (355M parameter) model. If your Colab instance doesn't have enough GPU space, you may need to switch to the small-size (124M parameter) model, but the results will be less impressive.

# %%
from torchvision.models import resnet152
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, Dataset
import torch
from torch import optim, nn
import zipfile
from google.colab import files
import os
import sys
from PIL import Image, ImageOps
from tqdm import tqdm
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1 Fine-tune a ResNet for image classification

# %% [markdown]
# ### 1.1 Find a dataset to fine-tune on, and make a Dataset class (1 hr.)

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Inherit from torch.utils.data.Dataset
# - Use a [torchvision.datasets.ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#torchvision.datasets.ImageFolder)
# - Don't spend too long finding another dataset. Some suggestions that you are free to use:
#  - https://www.kaggle.com/jessicali9530/stanford-dogs-dataset
#  - https://www.kaggle.com/puneet6060/intel-image-classification

# %% [markdown]
# #### Help for downloading kaggle datasets
# Downloading Kaggle datasets requires authentication, so you can't just download from a url. Here are some step-by-step instructions of how to get Kaggle datasets in Colab

# %% [markdown]
# 1. Create an API key in Kaggle
#     - Click on profile photo
#     - Go to 'My Account'
#     - Scroll down to the API access section and click "Create New API Token"
#     - `kaggle.json` is now downloaded to your computer
#
# 2. Upload the API key and install the Kaggle API client by running the next cell (run it again if it throws an error the first time). Also, `files.upload()` may not work in Firefox. One solution is to expand the Files banner (indicated by the '>' tab on the left side of the page) and use that to upload the key.

# %%
# Run this cell and select the kaggle.json file downloaded
# from the Kaggle account settings page.
from google.colab import files
files.upload()
# Next, install the Kaggle API client.
# !pip install -q kaggle
# Let's make sure the kaggle.json file is present.
# !ls -lha kaggle.json
# The Kaggle API client expects this file to be in ~/.kaggle,
# so move it there.
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-f1e179ce-8648-488b-aac5-0eabbfe52a2a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1e179ce-8648-488b-aac5-0eabbfe52a2a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# -rw-r--r-- 1 root root 72 Nov  5 17:39 kaggle.json

# %% [markdown]
# 3. Copy the desired dataset locally

# %%
# Example download command for dataset found here: https://www.kaggle.com/akash2907/bird-species-classification
# !kaggle datasets download -d akash2907/bird-species-classification
# Out:
# bird-species-classification.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# #### Make the Dataset class
# See the implementation below for reference, and implement a dataset class for the dataset you choose.

# %%
class BirdDataset(Dataset):
    def __init__(self, zip_file='bird-species-classification.zip', size=256, train=True, upload=False):
        super(BirdDataset, self).__init__()
        
        self.train = train
        extract_dir = os.path.splitext(zip_file)[0]
        if not os.path.exists(extract_dir):
            os.makedirs(extract_dir)
            self.extract_zip(zip_file, extract_dir)
            # Resize the images - originally they are high resolution. We could do this
            # in the DataLoader, but it will read the full-resolution files from disk
            # every time before resizing them, making training slow
            self.resize(extract_dir, size=size)

        postfix = 'train' if train else 'test'
            
        if train:
            # The bird-species dataset mistakenly has a train_data folder inside of train_data
            self.dataset_folder = datasets.ImageFolder(os.path.join(extract_dir, 'train_data', 'train_data'), transform=transforms.Compose([transforms.ToTensor()]))
        else:
            self.dataset_folder = datasets.ImageFolder(os.path.join(extract_dir, 'test_data', 'test_data'), transform=transforms.Compose([transforms.ToTensor()]))

    def extract_zip(self, zip_file, extract_dir):
        print("Extracting", zip_file)
        with zipfile.ZipFile(zip_file, 'r') as zip_ref:
            zip_ref.extractall(extract_dir)

    def resize(self, path, size=256):
        """Resizes all images in place"""
        print("Resizing images")
        dirs = os.walk(path)
        for root, dirs, files in os.walk(path):
            for item in files:
                name = os.path.join(root, item)
                if os.path.isfile(name):
                    im = Image.open(name)
                    im = ImageOps.fit(im, (size, size))
                    im.save(name[:-3] + 'bmp', 'BMP')
                    os.remove(name)

    def __getitem__(self, i):
        return self.dataset_folder[i]

    def __len__(self):
        return len(self.dataset_folder)

bird_data = BirdDataset()

# %%
#########################
# Implement your own Dataset
#########################

# %% [markdown]
# ### 1.2 Wrap a pretrained ResNet in an `nn.Module` (30 min)

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Make a model class that inherits from `nn.Module`
# - Wrap a pretrained ResNet and swap out the last layer of that network with a layer that maps to the number of classes in your new dataset

# %% [markdown]
# #### Make your model class

# %%
class CustomResNet(nn.Module):
    def __init__(self, num_classes, start_frozen=False):
        super(CustomResNet, self).__init__()

        # Part 1.2
        # Load the model - make sure it is pre-trained
        self.model = resnet152(pretrained=True)

        # Part 1.4
        if start_frozen:
            # Turn off all gradients of the resnet
            for param in self.model.parameters():
              param.requires_grad = False
        
        # Part 1.2
        # Look at the code of torchvision.models.resnet152 (or print the ResNet object) to find the name of the attribute to override (the last layer of the ResNet)
        # Override the output linear layer of the neural network to map to the correct number of classes. Note that this new layer has requires_grad = True
        self.model.fc = nn.Linear(self.model.fc.in_features, num_classes)
        
    def unfreeze(self, n_layers):
        # Part 1.4
        # Turn on gradients for the last n_layers
        cnt = 0
        for name, param in reversed(list(self.model.named_parameters())):
          if cnt == n_layers:
            break
          if name.find("conv") != -1:
            param.requires_grad = True
            cnt += 1

        # params = list(self.model.parameters())
        # start = len(params) - 1
        # stop = start - n_layers
        # for i in range(start, stop, -1):
        #   params[i].requires_grad = True

    def forward(self, x):
        # Part 1.2
        # Pass x through the resnet
        return self.model(x)

# %% [markdown]
# ### 1.3 Read through and run this training loop

# %%
def accuracy(y_hat, y_truth):
    """Gets average accuracy of a vector of predictions"""
    
    preds = torch.argmax(y_hat, dim=1)
    acc = torch.mean((preds == y_truth).float())
    return acc

def evaluate(model, objective, val_loader, device):
    """Gets average accuracy and loss for the validation set"""

    val_losses = 0
    val_accs = 0
    batches = 0
    # model.eval() so that batchnorm and dropout work in eval mode
    model.eval()
    # torch.no_grad() to turn off computation graph creation. This allows for temporal
    # and spatial complexity improvements, which allows for larger validation batch 
    # sizes so it’s recommended
    with torch.no_grad():
        for x, y_truth in val_loader:
            
            batches += 1

            x, y_truth = x.to(device), y_truth.to(device)
            y_hat = model(x)
            val_loss = objective(y_hat, y_truth)
            val_acc = accuracy(y_hat, y_truth)

            val_losses += val_loss.item()
            val_accs += val_acc

    model.train()

    return val_losses/batches, val_accs/batches

# %%
def train(start_frozen=False, model_unfreeze=0):
    """Fine-tunes a CNN
    Args:
        start_frozen (bool): whether to start with the network weights frozen.
        model_unfreeze (int): the maximum number of network layers to unfreeze
    """
    epochs = 20
    # Start with a very low learning rate
    lr = .00005
    val_every = 3
    num_classes = 16
    batch_size = 32
    device = torch.device('cuda:0')

    # Data
    # TODO: Use your own dataset
    # train_dataset = CustomDataset(upload=True, train=True)
    # val_dataset = CustomDataset(upload=True, train=False)
    train_dataset = BirdDataset(upload=True, train=True)
    val_dataset = BirdDataset(upload=True, train=False)
    train_loader = DataLoader(train_dataset,
                              shuffle=True,
                              num_workers=8,
                              batch_size=batch_size)
    val_loader = DataLoader(val_dataset,
                              shuffle=True,
                              num_workers=8,
                              batch_size=batch_size)
    
    # Model
    model = CustomResNet(num_classes, start_frozen=start_frozen).to(device)
    
    # Objective
    objective = nn.CrossEntropyLoss()
    # Optimizer
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-1)

    # Progress bar
    pbar = tqdm(total=len(train_loader) * epochs)

    train_losses = []
    train_accs = []
    val_losses = []
    val_accs = []
    
    cnt = 0
    for epoch in range(epochs):

        # Implement model unfreezing
        if epoch < model_unfreeze:
            # Part 1.4
            # Unfreeze the last layers, one more each epoch
            model.unfreeze(epoch)
        
        for x, y_truth in train_loader:
        
            x, y_truth = x.to(device), y_truth.to(device)

            optimizer.zero_grad()

            y_hat = model(x)
            train_loss = objective(y_hat, y_truth)
            train_acc = accuracy(y_hat, y_truth)

            train_loss.backward()
            optimizer.step()

            train_accs.append(train_acc)
            train_losses.append(train_loss.item())

            if cnt % val_every == 0:
                val_loss, val_acc = evaluate(model, objective, val_loader, device)
                val_losses.append(val_loss)
                val_accs.append(val_acc)

            pbar.set_description('train loss:{:.4f}, train accuracy:{:.4f}.'.format(train_loss.item(), train_acc))
            pbar.update(1)
            cnt += 1

    pbar.close()
    plt.subplot(121)
    plt.plot(np.arange(len(train_accs)), train_accs, label='Train Accuracy')
    plt.plot(np.arange(len(train_accs), step=val_every), val_accs, label='Val Accuracy')
    plt.legend()
    plt.subplot(122)
    plt.plot(np.arange(len(train_losses)), train_losses, label='Train Loss')
    plt.plot(np.arange(len(train_losses), step=val_every), val_losses, label='Val Loss')
    plt.legend()
    plt.show()

# %%
train(start_frozen=False, model_unfreeze=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss:2.7958, train accuracy:0.0312.:   0%|          | 0/100 [00:02<?, ?it/s]
# train loss:2.7958, train accuracy:0.0312.:   1%|          | 1/100 [00:02<04:12,  2.55s/it]
# train loss:2.7515, train accuracy:0.0938.:   1%|          | 1/100 [00:03<04:12,  2.55s/it]
# train loss:2.7515, train accuracy:0.0938.:   2%|▏         | 2/100 [00:03<02:15,  1.39s/it]
# train loss:2.8106, train accuracy:0.1250.:   2%|▏         | 2/100 [00:03<02:15,  1.39s/it]
# train loss:2.8106, train accuracy:0.1250.:   3%|▎         | 3/100 [00:03<01:37,  1.01s/it]
# train loss:2.5932, train accuracy:0.3125.:   3%|▎         | 3/100 [00:05<01:37,  1.01s/it]
# train loss:2.5932, train accuracy:0.3125.:   4%|▍         | 4/100 [00:05<02:17,  1.43s/it]
# train loss:2.6117, train accuracy:0.2727.:   4%|▍         | 4/100 [00:06<02:17,  1.43s/it]
# train loss:2.6117, train accuracy:0.2727.:   5%|▌         | 5/100 [00:06<01:42,  1.08s/it]
# train loss:2.3644, train accuracy:0.5000.:   5%|▌         | 5/100 [00:07<01:42,  1.08s/it]
# train loss:2.3644, train accuracy:0.5000.:   6%|▌         | 6/100 [00:07<01:45,  1.13s/it]
# train loss:2.1288, train accuracy:0.6562.:   6%|▌         | 6/100 [00:09<01:45,  1.13s/it]
# train loss:2.1288, train accuracy:0.6562.:   7%|▋         | 7/100 [00:09<02:14,  1.44s/it]
# train loss:2.2005, train accuracy:0.5938.:   7%|▋         | 7/100 [00:10<02:14,  1.44s/it]
# train loss:2.2005, train accuracy:0.5938.:   8%|▊         | 8/100 [00:10<01:46,  1.16s/it]
# train loss:2.0160, train accuracy:0.7812.:   8%|▊         | 8/100 [00:10<01:46,  1.16s/it]
# train loss:2.0160, train accuracy:0.7812.:   9%|▉         | 9/100 [00:10<01:28,  1.03it/s]
# train loss:2.0240, train accuracy:0.6818.:   9%|▉         | 9/100 [00:12<01:28,  1.03it/s]
# train loss:2.0240, train accuracy:0.6818.:  10%|█         | 10/100 [00:12<01:55,  1.29s/it]
# train loss:1.8356, train accuracy:0.9062.:  10%|█         | 10/100 [00:13<01:55,  1.29s/it]
# train loss:0.0979, train accuracy:1.0000.:  95%|█████████▌| 95/100 [01:52<00:05,  1.07s/it]
# train loss:0.0795, train accuracy:1.0000.:  95%|█████████▌| 95/100 [01:53<00:05,  1.07s/it]
# train loss:0.0795, train accuracy:1.0000.:  96%|█████████▌| 96/100 [01:53<00:04,  1.12s/it]
# train loss:0.0691, train accuracy:1.0000.:  96%|█████████▌| 96/100 [01:55<00:04,  1.12s/it]
# train loss:0.0691, train accuracy:1.0000.:  97%|█████████▋| 97/100 [01:55<00:04,  1.42s/it]
# train loss:0.0972, train accuracy:1.0000.:  97%|█████████▋| 97/100 [01:56<00:04,  1.42s/it]
# train loss:0.0972, train accuracy:1.0000.:  98%|█████████▊| 98/100 [01:56<00:02,  1.15s/it]
# train loss:0.0866, train accuracy:1.0000.:  98%|█████████▊| 98/100 [01:57<00:02,  1.15s/it]
# train loss:0.0866, train accuracy:1.0000.:  99%|█████████▉| 99/100 [01:57<00:00,  1.03it/s]
# train loss:0.1709, train accuracy:1.0000.:  99%|█████████▉| 99/100 [01:59<00:00,  1.03it/s]
# train loss:0.1709, train accuracy:1.0000.: 100%|██████████| 100/100 [01:59<00:00,  1.19s/it]

# %% [markdown]
# ### 1.4 Implement Unfreezing (1 hr)

# %% [markdown]
# #### Description

# %% [markdown]
# Unfreezing is a technique that can be helpful when fine tuning a CNN for a more difficult task with a large amount of data.
#
# The idea is that if we allow the network to tweak the earliest layers immediately, before the last FCL has been trained at all, the earliest layers will forget all of the useful features that they learned in order  to provide features that are helpful for the (untrained) FCL.
#
# So, rather than training all of the model weights at once, we learn the last fully connected layer, then train that layer together with the second-to-last layer, gradually adding layers until we reach the first layer.

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Modify your model's parameters by setting the `requires_grad` attributes to `False`. (but keep `requires_grad = True` for the last layer).
# - Add a member function to you model class that allows the user to unfreeze weights in the training loop. See [this github gist](https://gist.github.com/jcjohnson/6e41e8512c17eae5da50aebef3378a4c) for reference.
# - Modify your training loop to add logic that calls the `unfreeze` function of the model class: unfreeze one layer (a convolutional layer or linear layer, not the sequential or bottleneck layers) every epoch.
# - Call your train function to fine-tune the ResNet on your dataset.

# %%
# print(resnet152(pretrained=True))
# model = resnet152(pretrained=True)
# for name, param in reversed(list(model.named_parameters())):
#   print(name)

# %% [markdown]
# #### Call your train function

# %%
############################
# train with unfreezing here (should be a single call to your train function)
############################
train(start_frozen=False, model_unfreeze=len(list(resnet152(pretrained=True).parameters())))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train loss:0.0943, train accuracy:1.0000.: 100%|██████████| 100/100 [02:01<00:00,  1.21s/it]

# %% [markdown]
# You may not see any improvement for your classification task, but unfreezing can help convergence for more difficult image classification tasks.

# %% [markdown]
# ## 2 Fine-tune a language model - (15 min)

# %% [markdown]
# In this section you will use the gpt-2-simple package [here](https://github.com/minimaxir/gpt-2-simple) to fine-tune the GPT-2 language model on a domain of your choice.

# %% [markdown]
# ### 2.1 Generate text from an the pretrained GPT-2 model

# %% [markdown]
# #### Run this code to generate text from a pretrained model

# %%
# !pip install gpt-2-simple

# the transformers package is built on top of Tensorflow, and the default TF version 
# for Colab will soon switch to 2.x. We remedy this with the following magic method
# %tensorflow_version 1.x 

import gpt_2_simple as gpt2
import os
import tensorflow as tf
# Out:
# Requirement already satisfied: gpt-2-simple in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: tensorflow>=2.5.1 in /usr/local/lib/python3.7/dist-packages (from gpt-2-simple) (2.6.0)
# Requirement already satisfied: toposort in /usr/local/lib/python3.7/dist-packages (from gpt-2-simple) (1.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gpt-2-simple) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gpt-2-simple) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from gpt-2-simple) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from gpt-2-simple) (2019.12.20)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.17.3)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.6.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.41.0)
# Requirement already satisfied: keras~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (2.6.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.1.2)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.12.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.12.1)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.37.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (2.6.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.1.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.2.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (2.6.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.3.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.4.0)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (5.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.12)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.7.4.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow>=2.5.1->gpt-2-simple) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (57.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gpt-2-simple) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gpt-2-simple) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gpt-2-simple) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gpt-2-simple) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (3.6.0)
# TensorFlow 1.x selected.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# This line is necessary to be able to run a new tf session
tf.reset_default_graph()
# The medium-sized model. IF you run out of memory, try "124M" instead
model_name = "124M"
if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)   # model is saved into current directory under /models/124M/

sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, model_name=model_name)
gpt2.generate(sess, model_name=model_name)
# Out:
# Loading pretrained model models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# If you have a Leaflet
#
# If you have an Echo
#
# If you have a Koons
#
# If you have a Ponieshead
#
# If you have a Sunflower
#
# If you have a Poy
#
# If you have a Red
#
# If you have a Silver
#
# If you have a White
#
# If you have a Black
#
# If you have a White
#
# If you have a Silver
#
# If you have a White
#
# If you have a Black
#
# If you have a White
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a White
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you have a Black
#
# If you

# %% [markdown]
# ### 2.2 Download a text dataset

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Use the provided functions to download your own text dataset
# - [Project Gutenberg](https://www.gutenberg.org/) is a nice starting point for raw text corpora

# %% [markdown]
# #### Download Dataset

# %%
import zipfile
import os
from torchvision import datasets

def extract_zip(zip_path, remove_finished=True):
    print('Extracting {}'.format(zip_path))
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(zip_path.replace('.zip', ''))
    if remove_finished:
        os.remove(zip_path)

def download_dataset(url, root='../data'):
    if not os.path.exists(os.path.join(root, 'text')):
        os.makedirs(os.path.join(root))
        datasets.utils.download_url(url, root, 'text.zip', None)
        extract_zip(os.path.join(root, 'text.zip'))
    return os.path.join(root, 'text')

##########################################
# Set the url for your dataset here,
# move the dataset to the desired location
##########################################
url = 'https://www.gutenberg.org/files/30/30.zip'
download_dataset(url)
# !mv /data/text/30.txt /data/text/bible.txt
# !ls ../data/text
# Out:
# mv: cannot stat '/data/text/30.txt': No such file or directory
# bible.txt

# %% [markdown]
# ### 2.3 Fine-tune GPT-2 on your own dataset

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Swap out the dataset parameter with the path to your dataset

# %% [markdown]
# #### Train on your dataset

# %%
# This line is necessary to be able to run a new tf session if one has already been run
tf.reset_default_graph()
# Start a session
sess = gpt2.start_tf_sess()
# Fine tune `model_name` on `data`
###################################
# Swap out the `dataset` parameter with the path to your text dataset
###################################
gpt2.finetune(sess,
              dataset='../data/text/bible.txt',
              model_name=model_name,
              restore_from='latest',
              steps=500)   # steps is max number of training steps

gpt2.generate(sess, run_name='run1')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:06<00:00,  6.46s/it]
# dataset has 1788810 tokens
# Training...
# [1 | 6.18] loss=2.23 avg=2.23
# [2 | 7.43] loss=2.38 avg=2.31
# [3 | 8.68] loss=2.66 avg=2.42
# [4 | 9.93] loss=1.91 avg=2.29
# [5 | 11.17] loss=1.99 avg=2.23
# [6 | 12.42] loss=2.18 avg=2.22
# [7 | 13.67] loss=2.07 avg=2.20
# [8 | 14.91] loss=2.09 avg=2.19
# [9 | 16.16] loss=1.92 avg=2.15
# [10 | 17.41] loss=1.96 avg=2.13
# [11 | 18.66] loss=1.82 avg=2.10
# [12 | 19.90] loss=1.86 avg=2.08
# [13 | 21.16] loss=1.89 avg=2.07
# [14 | 22.40] loss=1.89 avg=2.05
# [15 | 23.65] loss=1.88 avg=2.04
# [16 | 24.91] loss=1.92 avg=2.03
# [17 | 26.15] loss=1.75 avg=2.01
# [18 | 27.39] loss=1.94 avg=2.01
# [19 | 28.64] loss=1.84 avg=2.00
# [20 | 29.88] loss=1.80 avg=1.99
# [21 | 31.13] loss=1.85 avg=1.98
# [22 | 32.37] loss=1.83 avg=1.97
# [23 | 33.62] loss=1.97 avg=1.97
# [24 | 34.86] loss=1.65 avg=1.96
# [25 | 36.11] loss=1.91 avg=1.96
# [26 | 37.35] loss=1.80 avg=1.95
# [27 | 38.60] loss=1.70 avg=1.94
# [28 | 39.85] loss=1.77 avg=1.93
# [29 | 41.09] loss=1.80 avg=1.93
# [30 | 42.34] loss=1.89 avg=1.93
# [31 | 43.59] loss=1.88 avg=1.92
# [32 | 44.83] loss=1.73 avg=1.92
# [33 | 46.07] loss=1.66 avg=1.91
# [34 | 47.32] loss=1.69 avg=1.90
# [35 | 48.57] loss=1.79 avg=1.90
# [36 | 49.81] loss=1.76 avg=1.89
# [37 | 51.06] loss=1.87 avg=1.89
# [38 | 52.31] loss=1.72 avg=1.89
# [39 | 53.56] loss=1.52 avg=1.87
# [40 | 54.81] loss=1.66 avg=1.87
# [41 | 56.05] loss=1.60 avg=1.86
# [42 | 57.31] loss=1.82 avg=1.86
# [43 | 58.56] loss=1.58 avg=1.85
# [44 | 59.81] loss=1.80 avg=1.85
# [45 | 61.05] loss=1.81 avg=1.85
# [46 | 62.30] loss=1.75 avg=1.85
# [47 | 63.55] loss=1.72 avg=1.84
# [48 | 64.79] loss=1.76 avg=1.84
# [49 | 66.05] loss=1.76 avg=1.84
# [50 | 67.29] loss=1.78 avg=1.84
# [51 | 68.54] loss=1.66 avg=1.83
# [52 | 69.79] loss=1.86 avg=1.83
# [53 | 71.04] loss=1.71 avg=1.83
# [54 | 72.29] loss=1.75 avg=1.83
# [55 | 73.55] loss=1.67 avg=1.82
# [56 | 74.79] loss=1.67 avg=1.82
# [57 | 76.05] loss=1.81 avg=1.82
# [58 | 77.30] loss=1.79 avg=1.82
# [59 | 78.55] loss=1.76 avg=1.82
# [60 | 79.80] loss=1.73 avg=1.82
# [61 | 81.05] loss=1.70 avg=1.81
# [62 | 82.29] loss=1.88 avg=1.82
# [63 | 83.54] loss=1.78 avg=1.81
# [64 | 84.78] loss=1.71 avg=1.81
# [65 | 86.03] loss=1.88 avg=1.81
# [66 | 87.28] loss=1.77 avg=1.81
# [67 | 88.52] loss=1.70 avg=1.81
# [68 | 89.78] loss=1.68 avg=1.81
# [69 | 91.02] loss=1.66 avg=1.81
# [70 | 92.27] loss=1.76 avg=1.80
# [71 | 93.53] loss=1.65 avg=1.80
# [72 | 94.78] loss=1.70 avg=1.80
# [73 | 96.03] loss=1.84 avg=1.80
# [74 | 97.27] loss=1.65 avg=1.80
# [75 | 98.52] loss=1.68 avg=1.79
# [76 | 99.77] loss=1.67 avg=1.79
# [77 | 101.02] loss=1.74 avg=1.79
# [78 | 102.26] loss=1.73 avg=1.79
# [79 | 103.51] loss=1.73 avg=1.79
# [80 | 104.76] loss=1.69 avg=1.79
# [81 | 106.00] loss=1.66 avg=1.79
# [82 | 107.25] loss=1.86 avg=1.79
# [83 | 108.50] loss=1.77 avg=1.79
# [84 | 109.75] loss=1.60 avg=1.78
# [85 | 111.00] loss=1.72 avg=1.78
# [86 | 112.25] loss=1.66 avg=1.78
# [87 | 113.50] loss=1.71 avg=1.78
# [88 | 114.74] loss=1.73 avg=1.78
# [89 | 115.99] loss=1.59 avg=1.77
# [90 | 117.24] loss=1.65 avg=1.77
# [91 | 118.50] loss=1.70 avg=1.77
# [92 | 119.74] loss=1.51 avg=1.77
# [93 | 120.99] loss=1.62 avg=1.76
# [94 | 122.23] loss=1.58 avg=1.76
# [95 | 123.48] loss=1.69 avg=1.76
# [96 | 124.73] loss=1.74 avg=1.76
# [97 | 125.97] loss=1.66 avg=1.76
# [98 | 127.22] loss=1.57 avg=1.76
# [99 | 128.48] loss=1.69 avg=1.75
# [100 | 129.72] loss=1.60 avg=1.75
# ======== SAMPLE 1 ========
#        in the way of the LORD: the sea shall be cleansed from thee; the waters of the
#            pit shall be clean; but all the water that shall be
#            on her face shall be dried up.
#
# 19:004:001 And hearkened thou not unto the words of Moses, and
#            to the things which Joshua was in the wilderness from the
#            beginning to the destruction of the bush in the east, and was
#            in captivity in the wilderness of Zotah.
#
# 19:004:002 And then he rebuked Moses, saying, Master,
#            what shall be the way unto the land of Canaan, when it
#            shall fall into thee? and the water of the pit shall
#            become clean: but the land of Judah shall be dry,
#            as that it was before the fire.
#
# 19:004:003 Then he rebuked Moses, saying, Master, what shall be
#            the way unto Israel? and they departed unto the wilderness from
#            the beginning of the wilderness before the fire.
#
# 19:004:004 And therefore said Moses unto Moses, Go now to the
#            land of Nun: the east, that is, the land of Nun, wherein
#            the fire is, shall be clean; as there shall be no stink
#            on the land of Nun; even as there shall be no
#            stink on the land of Nun; or as there shall be no
#            stink on the land of Nun: for Israel will not go,
#            or go.
#
# 19:004:005 And therefore said Moses unto Moses, Go now unto the east of
#            the land of Nun, and take not it: the earth shall be
#            clean.
#
# 19:004:006 And thus said Moses unto his own household, Take your
#            sheep, that they may be brought with thee down into the wilderness; and
#            let them go, that they may go about in peace: and they go
#            over to the wilderness, and are not polluted: for
#            Israel will not go: for the land of Nun shall be dry.
#
# 19:004:007 And therefore said the Levites unto Moses, Let
#            us behold that waters run through all the land of the Canaanite
#            people on all sides, as it was before the fire; as
#            then shall the land of Nun be clean.
#
# 19:004:008 And the Levites did not know that we were in the wilderness from the
#            beginning to the destruction of the bush in the east,
#            where Joshua was in captivity in the wilderness, and yet
#            were in captivity in the wilderness of Zotah; then the
#            people of Canaan, and the people of Jerusalem, were
#            washed up in the wilderness.
#
# 19:004:009 And therefore said the Levites unto Moses, Let us put
#            us up for the way; and let us return to our place.
#
# 19:004:010 And thus said Moses unto the people of the land, Return
#            unto us the way through all the land of Canaan, to the
#            westward of Jerusalem; and we shall set a pleasant way round to
#            the water of the pool, and to the hill of the fire, and
#            to the hill of the
#
# [101 | 139.99] loss=1.62 avg=1.75
# [102 | 141.23] loss=1.76 avg=1.75
# [103 | 142.48] loss=1.67 avg=1.75
# [104 | 143.73] loss=1.66 avg=1.75
# [105 | 144.97] loss=1.62 avg=1.75
# [106 | 146.23] loss=1.66 avg=1.74
# [107 | 147.48] loss=1.65 avg=1.74
# [108 | 148.72] loss=1.66 avg=1.74
# [109 | 149.97] loss=1.67 avg=1.74
# [110 | 151.24] loss=1.62 avg=1.74
# [111 | 152.49] loss=1.62 avg=1.74
# [112 | 153.73] loss=1.48 avg=1.73
# [113 | 154.98] loss=1.70 avg=1.73
# [114 | 156.23] loss=1.58 avg=1.73
# [115 | 157.48] loss=1.67 avg=1.73
# [116 | 158.72] loss=1.61 avg=1.73
# [117 | 159.97] loss=1.62 avg=1.73
# [118 | 161.22] loss=1.73 avg=1.73
# [119 | 162.47] loss=1.63 avg=1.72
# [120 | 163.72] loss=1.55 avg=1.72
# [121 | 164.97] loss=1.60 avg=1.72
# [122 | 166.23] loss=1.77 avg=1.72
# [123 | 167.47] loss=1.77 avg=1.72
# [124 | 168.72] loss=1.79 avg=1.72
# [125 | 169.97] loss=1.73 avg=1.72
# [126 | 171.22] loss=1.71 avg=1.72
# [127 | 172.47] loss=1.67 avg=1.72
# [128 | 173.71] loss=1.78 avg=1.72
# [129 | 174.96] loss=1.69 avg=1.72
# [130 | 176.21] loss=1.60 avg=1.72
# [131 | 177.45] loss=1.52 avg=1.72
# [132 | 178.70] loss=1.57 avg=1.72
# [133 | 179.94] loss=1.55 avg=1.71
# [134 | 181.20] loss=1.55 avg=1.71
# [135 | 182.45] loss=1.54 avg=1.71
# [136 | 183.69] loss=1.54 avg=1.71
# [137 | 184.94] loss=1.65 avg=1.71
# [138 | 186.19] loss=1.72 avg=1.71
# [139 | 187.44] loss=1.64 avg=1.71
# [140 | 188.69] loss=1.58 avg=1.70
# [141 | 189.94] loss=1.47 avg=1.70
# [142 | 191.19] loss=1.74 avg=1.70
# [143 | 192.43] loss=1.65 avg=1.70
# [144 | 193.68] loss=1.43 avg=1.70
# [145 | 194.92] loss=1.60 avg=1.70
# [146 | 196.17] loss=1.63 avg=1.69
# [147 | 197.42] loss=1.50 avg=1.69
# [148 | 198.66] loss=1.80 avg=1.69
# [149 | 199.91] loss=1.57 avg=1.69
# [150 | 201.17] loss=1.64 avg=1.69
# [151 | 202.42] loss=1.63 avg=1.69
# [152 | 203.67] loss=1.68 avg=1.69
# [153 | 204.91] loss=1.63 avg=1.69
# [154 | 206.17] loss=1.56 avg=1.69
# [155 | 207.42] loss=1.52 avg=1.69
# [156 | 208.67] loss=1.59 avg=1.68
# [157 | 209.91] loss=1.74 avg=1.69
# [158 | 211.16] loss=1.53 avg=1.68
# [159 | 212.40] loss=1.59 avg=1.68
# [160 | 213.64] loss=1.50 avg=1.68
# [161 | 214.89] loss=1.73 avg=1.68
# [162 | 216.13] loss=1.75 avg=1.68
# [163 | 217.38] loss=1.66 avg=1.68
# [164 | 218.63] loss=1.59 avg=1.68
# [165 | 219.88] loss=1.72 avg=1.68
# [166 | 221.13] loss=1.56 avg=1.68
# [167 | 222.39] loss=1.67 avg=1.68
# [168 | 223.64] loss=1.66 avg=1.68
# [169 | 224.88] loss=1.52 avg=1.68
# [170 | 226.13] loss=1.52 avg=1.67
# [171 | 227.37] loss=1.67 avg=1.67
# [172 | 228.62] loss=1.76 avg=1.68
# [173 | 229.86] loss=1.74 avg=1.68
# [174 | 231.11] loss=1.58 avg=1.68
# [175 | 232.37] loss=1.64 avg=1.68
# [176 | 233.62] loss=1.64 avg=1.67
# [177 | 234.87] loss=1.73 avg=1.68
# [178 | 236.12] loss=1.56 avg=1.67
# [179 | 237.36] loss=1.53 avg=1.67
# [180 | 238.62] loss=1.61 avg=1.67
# [181 | 239.87] loss=1.58 avg=1.67
# [182 | 241.12] loss=1.66 avg=1.67
# [183 | 242.37] loss=1.49 avg=1.67
# [184 | 243.62] loss=1.63 avg=1.67
# [185 | 244.86] loss=1.64 avg=1.67
# [186 | 246.10] loss=1.51 avg=1.67
# [187 | 247.35] loss=1.64 avg=1.67
# [188 | 248.59] loss=1.55 avg=1.66
# [189 | 249.84] loss=1.59 avg=1.66
# [190 | 251.08] loss=1.61 avg=1.66
# [191 | 252.34] loss=1.65 avg=1.66
# [192 | 253.58] loss=1.58 avg=1.66
# [193 | 254.84] loss=1.58 avg=1.66
# [194 | 256.09] loss=1.65 avg=1.66
# [195 | 257.33] loss=1.69 avg=1.66
# [196 | 258.59] loss=1.60 avg=1.66
# [197 | 259.84] loss=1.71 avg=1.66
# [198 | 261.08] loss=1.64 avg=1.66
# [199 | 262.33] loss=1.64 avg=1.66
# [200 | 263.58] loss=1.54 avg=1.66
# ======== SAMPLE 1 ========
#      and
#          the land, and it was not inhabited for the land's
#           inhabitants.
#
# 18:009:021 But there were two countries which made their cities: first
#           the country which was called Ged, which was of the land of the
#           inhabitants which were born there of an old man called, and came
#           before Ged, whom God had given him in such a time, to dwell
#           there: the land which, lo and behold, was also called a city.
#
# 18:009:022 There are in the land of Ged, and in the land which is called
#           Israel, a city, called Jerusalem, which God made a city for
#           his people.
#
# 18:009:023 Then said David, Go, and bring me the inhabitants of the
#           land, that I may tell thee the land.
#
# 18:009:024 But David said unto him, Go now; and come, and tell me, how I
#           am come, that I have not seen thee before, nor heard you
#           before me before this day.
#
# 18:009:025 And what shall I do? I am come by night, I am not seen.
#
# 18:009:026 And David went, and brought me all the inhabitants of the country
#           which is called Jerusalem, which are of Ged.
#
# 18:009:027 But they that live there are strangers, and no one can tell me
#           how to live there.
#
# 18:009:028 Now when they are come to Ged, who dwelleth in Jerusalem, which
#           is called Jerusalem, and there is yet peace, they shall know how
#           there shall be peace: and when they are come to Jerusalem, all the
#           land that is called Jerusalem shall know how ye shall find peace.
#
# 18:009:029 And when they be come to Jerusalem, Israel shall know that peace
#           ye shall find on the place of the war that is called the battle.
#
# 18:009:030 And when Israel shall come to Jerusalem to know ye, and how shall they
#           be able to know ye, even that ye made the land before all men to
#           be? and what shall ye do? for they shall be afraid.
#
# 18:009:031 And Israel shall also fear, and the fear in the land because of it is
#           not known.
#
# Chapter 20:004 The Destruction of the Children of Israel
#
# 18:004:001 The Children.
#
# 18:004:002 The wicked shall take vengeance on them whom they have set
#           over against Jerusalem, to bring them into the midst of the midst of
#           Israel: that they may know when there shall come a battle with them: they
#           shall then be their enemies.
#
# 18:004:003 But the children of Israel have destroyed Jerusalem, neither have they
#           been made his enemies to destroy Jerusalem; they shall not then go
#           into the land of the children of Israel to see the battle; they
#           shall not be the spoil of that which they slew, nor the spoil that
#           they slew.
#
# 18:004:004 And the great cities of the children of Israel shall be desolate:
#           for the city's inhabitants shall take no rest.
#
# 18:004:005 And when the cities of the children of Israel be slain, and
#           the cities of the children of Israel slain shall be forgotten:
#           both their cities and their inhabitants shall eat not: for the enemy is
#           come, and avenge himself, and avenge the city.
#
# 18:004:006 And the cities of the children
#
# [201 | 272.75] loss=1.59 avg=1.66
# [202 | 274.00] loss=1.72 avg=1.66
# [203 | 275.24] loss=1.58 avg=1.66
# [204 | 276.49] loss=1.65 avg=1.66
# [205 | 277.74] loss=1.62 avg=1.66
# [206 | 278.98] loss=1.58 avg=1.66
# [207 | 280.23] loss=1.65 avg=1.66
# [208 | 281.48] loss=1.62 avg=1.66
# [209 | 282.73] loss=1.56 avg=1.65
# [210 | 283.97] loss=1.44 avg=1.65
# [211 | 285.22] loss=1.57 avg=1.65
# [212 | 286.47] loss=1.49 avg=1.65
# [213 | 287.73] loss=1.63 avg=1.65
# [214 | 288.98] loss=1.42 avg=1.65
# [215 | 290.22] loss=1.63 avg=1.65
# [216 | 291.47] loss=1.65 avg=1.65
# [217 | 292.72] loss=1.66 avg=1.65
# [218 | 293.96] loss=1.52 avg=1.65
# [219 | 295.21] loss=1.46 avg=1.64
# [220 | 296.45] loss=1.57 avg=1.64
# [221 | 297.69] loss=1.60 avg=1.64
# [222 | 298.94] loss=1.63 avg=1.64
# [223 | 300.19] loss=1.55 avg=1.64
# [224 | 301.45] loss=1.65 avg=1.64
# [225 | 302.69] loss=1.38 avg=1.64
# [226 | 303.95] loss=1.54 avg=1.64
# [227 | 305.19] loss=1.52 avg=1.64
# [228 | 306.44] loss=1.62 avg=1.64
# [229 | 307.69] loss=1.50 avg=1.63
# [230 | 308.93] loss=1.61 avg=1.63
# [231 | 310.18] loss=1.54 avg=1.63
# [232 | 311.43] loss=1.66 avg=1.63
# [233 | 312.67] loss=1.56 avg=1.63
# [234 | 313.92] loss=1.41 avg=1.63
# [235 | 315.17] loss=1.59 avg=1.63
# [236 | 316.42] loss=1.68 avg=1.63
# [237 | 317.67] loss=1.75 avg=1.63
# [238 | 318.92] loss=1.65 avg=1.63
# [239 | 320.17] loss=1.37 avg=1.63
# [240 | 321.43] loss=1.44 avg=1.63
# [241 | 322.68] loss=1.59 avg=1.63
# [242 | 323.93] loss=1.64 avg=1.63
# [243 | 325.18] loss=1.48 avg=1.62
# [244 | 326.43] loss=1.51 avg=1.62
# [245 | 327.67] loss=1.60 avg=1.62
# [246 | 328.92] loss=1.56 avg=1.62
# [247 | 330.16] loss=1.59 avg=1.62
# [248 | 331.41] loss=1.47 avg=1.62
# [249 | 332.65] loss=1.64 avg=1.62
# [250 | 333.90] loss=1.52 avg=1.62
# [251 | 335.15] loss=1.68 avg=1.62
# [252 | 336.39] loss=1.51 avg=1.62
# [253 | 337.64] loss=1.55 avg=1.62
# [254 | 338.89] loss=1.62 avg=1.62
# [255 | 340.14] loss=1.45 avg=1.62
# [256 | 341.38] loss=1.52 avg=1.62
# [257 | 342.63] loss=1.44 avg=1.61
# [258 | 343.88] loss=1.62 avg=1.61
# [259 | 345.12] loss=1.51 avg=1.61
# [260 | 346.37] loss=1.57 avg=1.61
# [261 | 347.61] loss=1.46 avg=1.61
# [262 | 348.86] loss=1.61 avg=1.61
# [263 | 350.10] loss=1.40 avg=1.61
# [264 | 351.35] loss=1.60 avg=1.61
# [265 | 352.60] loss=1.52 avg=1.61
# [266 | 353.85] loss=1.56 avg=1.61
# [267 | 355.11] loss=1.98 avg=1.61
# [268 | 356.36] loss=1.63 avg=1.61
# [269 | 357.61] loss=1.60 avg=1.61
# [270 | 358.85] loss=1.37 avg=1.61
# [271 | 360.10] loss=1.57 avg=1.61
# [272 | 361.35] loss=1.59 avg=1.61
# [273 | 362.60] loss=1.70 avg=1.61
# [274 | 363.84] loss=1.51 avg=1.61
# [275 | 365.09] loss=1.49 avg=1.61
# [276 | 366.33] loss=1.55 avg=1.61
# [277 | 367.58] loss=1.51 avg=1.60
# [278 | 368.82] loss=1.56 avg=1.60
# [279 | 370.07] loss=1.47 avg=1.60
# [280 | 371.32] loss=1.58 avg=1.60
# [281 | 372.57] loss=1.51 avg=1.60
# [282 | 373.82] loss=1.52 avg=1.60
# [283 | 375.07] loss=1.70 avg=1.60
# [284 | 376.32] loss=1.39 avg=1.60
# [285 | 377.56] loss=1.61 avg=1.60
# [286 | 378.81] loss=1.55 avg=1.60
# [287 | 380.05] loss=1.55 avg=1.60
# [288 | 381.30] loss=1.46 avg=1.60
# [289 | 382.55] loss=1.55 avg=1.60
# [290 | 383.80] loss=1.47 avg=1.60
# [291 | 385.05] loss=1.58 avg=1.59
# [292 | 386.30] loss=1.63 avg=1.60
# [293 | 387.56] loss=1.54 avg=1.59
# [294 | 388.81] loss=1.53 avg=1.59
# [295 | 390.07] loss=1.56 avg=1.59
# [296 | 391.32] loss=1.61 avg=1.59
# [297 | 392.57] loss=1.62 avg=1.59
# [298 | 393.82] loss=1.49 avg=1.59
# [299 | 395.07] loss=1.58 avg=1.59
# [300 | 396.32] loss=1.45 avg=1.59
# ======== SAMPLE 1 ========
#  T0119:021 And he said unto them, I have seen that a man of the children of Israel was a man of the
#            house of Jairus, and he told me many things which he would tell
#            him, and saith unto me, What shall I say unto you of God?
#
# 01:021:022 And they answered and said, Go forth, and speak unto the Lord thy God.
#
# 01:021:023 And he led them into Jairus, and they came into the
#            city which was called Sihon, and took the city of Saul and his
#            inhabitants, wherein he had taken the city: and Saul and
#            his inhabitants went forth in sackcloth; and they brought out
#            the tabernacle, and they put it into the fire: and in the
#            fire he smote them, and put them under fire; and as they
#            were taken by the fire, he smote them again.
#
# 01:022:001 Then they returned unto their place and their camp, and they
#            said, We come in to seek you. And they said, Come in, let us go
#            before thee.
#
# 01:022:002 And he sent messengers to him, saying, I am come to
#            ask you now. And they said, We shall bring thee away
#            from Samaria to Samaria. So he brought thee away, and he went
#             into Samaria, and began to fight.
#
# 01:022:003 And he took the sword in his hand, and said, I will shoot him
#             before thou: and the sword came with him about the same time.
#
# 01:022:004 And they went through Samaria, and they were taken out by
#             the smoke.
#
# 01:022:005 And the smoke was filled with a cloud; and they went by the
#             mouth of the city. And they departed.
#
# 01:022:006 Then the smoke became very thick, and there rose up
#             ashes upon the city; and the fire went out.
#
# 01:022:007 And two of Israel's princes cried unto the LORD, saying, What
#            are these men? and of whom are these ye?
#
# 01:022:008 And the LORD answered Moses, The prophets do prophesy with my
#            children when I come into Samaria unto Samaria, and they say
#            unto me, Hearken unto me: why have we been so
#            afraid against thy people? for the spirit of the LORD is good
#            for me. So they departed.
#
# 01:022:009 And the men of Samaria arose and went up from the city. And
#            they saw a man go up to the house of his father.
#
# 01:022:010 And the man said, Master, will we come in to
#            find bread? and they said, Bring us in unto the gate.
#
# 01:022:011 And he said, What are these men so mighty which come in to bring
#            us in?
#
# 01:022:012 And they spake unto the servant of the house of God, saying, Shall
#            there be enough for thee?
#
# 01:022:013 Then Moses said unto him, Ye have not a thousand; but it
#             I am able to come into you, being at ease.
#
# 01:022:014 And he said, Thus saith the LORD, This is all that are
#            come out of the house of men; and there shall he bring us
#            into his
#
# [301 | 405.56] loss=1.61 avg=1.59
# [302 | 406.81] loss=1.41 avg=1.59
# [303 | 408.06] loss=1.49 avg=1.59
# [304 | 409.31] loss=1.51 avg=1.59
# [305 | 410.55] loss=1.65 avg=1.59
# [306 | 411.80] loss=1.59 avg=1.59
# [307 | 413.05] loss=1.45 avg=1.59
# [308 | 414.30] loss=1.36 avg=1.58
# [309 | 415.55] loss=1.62 avg=1.59
# [310 | 416.81] loss=1.44 avg=1.58
# [311 | 418.05] loss=1.54 avg=1.58
# [312 | 419.31] loss=1.49 avg=1.58
# [313 | 420.56] loss=1.36 avg=1.58
# [314 | 421.80] loss=1.62 avg=1.58
# [315 | 423.05] loss=1.42 avg=1.58
# [316 | 424.30] loss=1.39 avg=1.58
# [317 | 425.55] loss=1.49 avg=1.58
# [318 | 426.80] loss=1.61 avg=1.58
# [319 | 428.05] loss=1.47 avg=1.58
# [320 | 429.30] loss=1.42 avg=1.57
# [321 | 430.56] loss=1.42 avg=1.57
# [322 | 431.80] loss=1.69 avg=1.57
# [323 | 433.05] loss=1.57 avg=1.57
# [324 | 434.30] loss=1.56 avg=1.57
# [325 | 435.54] loss=1.64 avg=1.57
# [326 | 436.79] loss=1.42 avg=1.57
# [327 | 438.04] loss=1.39 avg=1.57
# [328 | 439.29] loss=1.55 avg=1.57
# [329 | 440.54] loss=1.60 avg=1.57
# [330 | 441.78] loss=1.51 avg=1.57
# [331 | 443.03] loss=1.42 avg=1.57
# [332 | 444.28] loss=1.55 avg=1.57
# [333 | 445.53] loss=1.50 avg=1.57
# [334 | 446.78] loss=1.64 avg=1.57
# [335 | 448.03] loss=1.61 avg=1.57
# [336 | 449.28] loss=1.55 avg=1.57
# [337 | 450.53] loss=1.56 avg=1.57
# [338 | 451.78] loss=1.56 avg=1.57
# [339 | 453.02] loss=1.62 avg=1.57
# [340 | 454.27] loss=1.38 avg=1.57
# [341 | 455.52] loss=1.45 avg=1.57
# [342 | 456.76] loss=1.46 avg=1.56
# [343 | 458.01] loss=1.45 avg=1.56
# [344 | 459.26] loss=1.62 avg=1.56
# [345 | 460.51] loss=1.64 avg=1.56
# [346 | 461.76] loss=1.66 avg=1.57
# [347 | 463.01] loss=1.56 avg=1.57
# [348 | 464.26] loss=1.44 avg=1.56
# [349 | 465.52] loss=1.54 avg=1.56
# [350 | 466.76] loss=1.39 avg=1.56
# [351 | 468.01] loss=1.61 avg=1.56
# [352 | 469.26] loss=1.51 avg=1.56
# [353 | 470.51] loss=1.42 avg=1.56
# [354 | 471.75] loss=1.56 avg=1.56
# [355 | 473.00] loss=1.63 avg=1.56
# [356 | 474.25] loss=1.45 avg=1.56
# [357 | 475.50] loss=1.62 avg=1.56
# [358 | 476.75] loss=1.49 avg=1.56
# [359 | 477.99] loss=1.41 avg=1.56
# [360 | 479.24] loss=1.55 avg=1.56
# [361 | 480.49] loss=1.70 avg=1.56
# [362 | 481.74] loss=1.46 avg=1.56
# [363 | 482.99] loss=1.40 avg=1.56
# [364 | 484.24] loss=1.52 avg=1.56
# [365 | 485.49] loss=1.38 avg=1.56
# [366 | 486.74] loss=1.50 avg=1.55
# [367 | 487.98] loss=1.71 avg=1.56
# [368 | 489.23] loss=1.53 avg=1.56
# [369 | 490.47] loss=1.45 avg=1.55
# [370 | 491.72] loss=1.37 avg=1.55
# [371 | 492.97] loss=1.44 avg=1.55
# [372 | 494.22] loss=1.68 avg=1.55
# [373 | 495.47] loss=1.49 avg=1.55
# [374 | 496.72] loss=1.43 avg=1.55
# [375 | 497.97] loss=1.35 avg=1.55
# [376 | 499.22] loss=1.47 avg=1.55
# [377 | 500.46] loss=1.54 avg=1.55
# [378 | 501.71] loss=1.47 avg=1.55
# [379 | 502.95] loss=1.54 avg=1.55
# [380 | 504.20] loss=1.58 avg=1.55
# [381 | 505.44] loss=1.57 avg=1.55
# [382 | 506.70] loss=1.44 avg=1.55
# [383 | 507.95] loss=1.29 avg=1.54
# [384 | 509.19] loss=1.50 avg=1.54
# [385 | 510.44] loss=1.53 avg=1.54
# [386 | 511.68] loss=1.56 avg=1.54
# [387 | 512.93] loss=1.52 avg=1.54
# [388 | 514.18] loss=1.50 avg=1.54
# [389 | 515.42] loss=1.39 avg=1.54
# [390 | 516.68] loss=1.47 avg=1.54
# [391 | 517.92] loss=1.42 avg=1.54
# [392 | 519.17] loss=1.52 avg=1.54
# [393 | 520.42] loss=1.45 avg=1.54
# [394 | 521.67] loss=1.52 avg=1.54
# [395 | 522.91] loss=1.69 avg=1.54
# [396 | 524.16] loss=1.53 avg=1.54
# [397 | 525.41] loss=1.44 avg=1.54
# [398 | 526.65] loss=1.62 avg=1.54
# [399 | 527.90] loss=1.46 avg=1.54
# [400 | 529.14] loss=1.56 avg=1.54
# ======== SAMPLE 1 ========
# , the son of God, the God in whom I know not;
#            my brethren, to whom I have called by the name of the fathers, and the
#            prophets, and the ministers of the church:
#
# 18:001:001 There shall ye also be made manifest upon every good and good
#            thing: there shall I make you manifest not in the church, neither
#            in any other, that is, in the word of the Lord.
#
# 18:001:002 I have therefore left out of this present time a
#            small portion of my brethren the Holy Ghost, which is by nature
#            perfect in all things.
#
# 18:001:003 These things are they which I desire in mine own sight to say that I
#            have seen them, and have spoken them, and have said unto
#            you again, I will see you again for them, and they shall
#            return.
#
# 18:001:004 Then the Lord said unto John, Behold, I give you an
#            testimony.
#
# 18:001:005 Now what? Shall I speak again? I shall speak this
#            thing more, I pray you.
#
# 18:001:006 And John answered and said, This is why it is that they ask me to speak
#            this thing.
#
# 18:001:007 For I, being a man that believe not, but see not, it came to pass
#            that when I was a little old, I was instructed in matters of
#            judgment by the Holy Ghost.
#
# 18:001:008 And as the brethren of Jacob, who in the first month
#            were ordained of the elders, and were ordained to be priests,
#            sought that they should speak the thing that was spoken of
#            them, and believed not: and so they do.
#
# 18:001:009 And when they were ordained of a priest, they began
#            to speak, and said, That man that is the chief priests should
#            call for our elders, and teach us to walk in the faith:
#            and it hath been done.
#
# 18:001:010 Also that priest, and all his fellows that were with him, was
#            called to minister to Joseph:
#
# 18:001:011 And, behold, he that is called to minister was in his days,
#            that he that was ordained of the priests was ordained of the
#            elders, and was
#           ordained of them, and was ordained again by them.
#
# 18:001:012 And the same thing came to pass, when his ministry was finished,
#            that man of God had brought up Jacob, and he dwelt in Galilee, and
#            preached unto the people:
#
# 18:001:013 And Joseph saw that his ministry was great, and that he
#            was baptized, and set up; and that he also was buried.
#
# 18:001:014 And he that was ordained ministering went to Jerusalem, and
#            came unto Antioch; where he preached in the church, and his
#            name was taught.
#
# 18:001:015 And his name was not written in the book of scripture, only the
#            writing which he had written, and thereon also that which he had
#            written:
#
# 18:001:016 Moreover all things which he had ordained with authority to do
#            before his own hand: for he had anointed his brother in the
#            church; and he
#
# [401 | 538.22] loss=1.64 avg=1.54
# [402 | 539.47] loss=1.34 avg=1.54
# [403 | 540.72] loss=1.50 avg=1.54
# [404 | 541.97] loss=1.63 avg=1.54
# [405 | 543.22] loss=1.52 avg=1.54
# [406 | 544.46] loss=1.51 avg=1.54
# [407 | 545.71] loss=1.54 avg=1.54
# [408 | 546.96] loss=1.52 avg=1.54
# [409 | 548.20] loss=1.59 avg=1.54
# [410 | 549.45] loss=1.51 avg=1.54
# [411 | 550.69] loss=1.24 avg=1.54
# [412 | 551.94] loss=1.50 avg=1.54
# [413 | 553.19] loss=1.50 avg=1.53
# [414 | 554.43] loss=1.54 avg=1.53
# [415 | 555.69] loss=1.44 avg=1.53
# [416 | 556.94] loss=1.31 avg=1.53
# [417 | 558.19] loss=1.39 avg=1.53
# [418 | 559.43] loss=1.39 avg=1.53
# [419 | 560.68] loss=1.42 avg=1.53
# [420 | 561.93] loss=1.49 avg=1.53
# [421 | 563.18] loss=1.55 avg=1.53
# [422 | 564.43] loss=1.49 avg=1.53
# [423 | 565.67] loss=1.44 avg=1.53
# [424 | 566.92] loss=1.48 avg=1.53
# [425 | 568.17] loss=1.60 avg=1.53
# [426 | 569.41] loss=1.49 avg=1.53
# [427 | 570.66] loss=1.64 avg=1.53
# [428 | 571.91] loss=1.50 avg=1.53
# [429 | 573.16] loss=1.34 avg=1.53
# [430 | 574.41] loss=1.56 avg=1.53
# [431 | 575.65] loss=1.60 avg=1.53
# [432 | 576.91] loss=1.71 avg=1.53
# [433 | 578.16] loss=1.54 avg=1.53
# [434 | 579.41] loss=1.28 avg=1.53
# [435 | 580.65] loss=1.45 avg=1.52
# [436 | 581.90] loss=1.35 avg=1.52
# [437 | 583.15] loss=1.35 avg=1.52
# [438 | 584.40] loss=1.38 avg=1.52
# [439 | 585.64] loss=1.51 avg=1.52
# [440 | 586.89] loss=1.49 avg=1.52
# [441 | 588.14] loss=1.45 avg=1.52
# [442 | 589.39] loss=1.32 avg=1.52
# [443 | 590.64] loss=1.47 avg=1.52
# [444 | 591.89] loss=1.33 avg=1.51
# [445 | 593.14] loss=1.52 avg=1.51
# [446 | 594.39] loss=1.42 avg=1.51
# [447 | 595.63] loss=1.41 avg=1.51
# [448 | 596.88] loss=1.51 avg=1.51
# [449 | 598.13] loss=1.43 avg=1.51
# [450 | 599.37] loss=1.45 avg=1.51
# [451 | 600.62] loss=1.28 avg=1.51
# [452 | 601.87] loss=1.45 avg=1.51
# [453 | 603.11] loss=1.42 avg=1.51
# [454 | 604.36] loss=1.65 avg=1.51
# [455 | 605.60] loss=1.41 avg=1.51
# [456 | 606.85] loss=1.57 avg=1.51
# [457 | 608.10] loss=1.69 avg=1.51
# [458 | 609.35] loss=1.37 avg=1.51
# [459 | 610.60] loss=1.55 avg=1.51
# [460 | 611.85] loss=1.39 avg=1.51
# [461 | 613.10] loss=1.57 avg=1.51
# [462 | 614.34] loss=1.46 avg=1.51
# [463 | 615.59] loss=1.56 avg=1.51
# [464 | 616.84] loss=1.34 avg=1.51
# [465 | 618.09] loss=1.40 avg=1.51
# [466 | 619.33] loss=1.36 avg=1.50
# [467 | 620.58] loss=1.42 avg=1.50
# [468 | 621.83] loss=1.29 avg=1.50
# [469 | 623.07] loss=1.64 avg=1.50
# [470 | 624.32] loss=1.41 avg=1.50
# [471 | 625.58] loss=1.47 avg=1.50
# [472 | 626.83] loss=1.56 avg=1.50
# [473 | 628.08] loss=1.50 avg=1.50
# [474 | 629.33] loss=1.45 avg=1.50
# [475 | 630.58] loss=1.43 avg=1.50
# [476 | 631.83] loss=1.51 avg=1.50
# [477 | 633.08] loss=1.49 avg=1.50
# [478 | 634.33] loss=1.28 avg=1.50
# [479 | 635.57] loss=1.40 avg=1.50
# [480 | 636.82] loss=1.46 avg=1.50
# [481 | 638.07] loss=1.53 avg=1.50
# [482 | 639.31] loss=1.48 avg=1.50
# [483 | 640.56] loss=1.48 avg=1.50
# [484 | 641.81] loss=1.35 avg=1.50
# [485 | 643.06] loss=1.45 avg=1.50
# [486 | 644.31] loss=1.57 avg=1.50
# [487 | 645.56] loss=1.40 avg=1.49
# [488 | 646.81] loss=1.32 avg=1.49
# [489 | 648.06] loss=1.55 avg=1.49
# [490 | 649.31] loss=1.59 avg=1.49
# [491 | 650.56] loss=1.53 avg=1.50
# [492 | 651.81] loss=1.28 avg=1.49
# [493 | 653.05] loss=1.50 avg=1.49
# [494 | 654.29] loss=1.45 avg=1.49
# [495 | 655.54] loss=1.31 avg=1.49
# [496 | 656.78] loss=1.61 avg=1.49
# [497 | 658.03] loss=1.41 avg=1.49
# [498 | 659.28] loss=1.44 avg=1.49
# [499 | 660.53] loss=1.49 avg=1.49
# [500 | 661.78] loss=1.45 avg=1.49
# Saving checkpoint/run1/model-500
#                  and in the midst of the house of the LORD,
#
# 01:021:074 And he blessed the three witnesses of them, and the
#             holy men, and the elders, and the master of the house: and
#             they did all prosper.
#
# 01:021:075 And the elders and the masters of the house took the witnesses,
#             and the holy men, and all the congregation unto the
#             house of the LORD;
#
# 01:021:076 And blessed them, and said, The LORD hath chosen
#             Jacob to reign over the children of Israel; yea, the
#             children of Israel shall make his father king over the
#             children of Israel.
#
# 01:021:077 And they took the seven witnesses, and the holy men, and
#             all their instruments, and all the congregation, and all the
#             congregation.
#
# 01:021:078 And the holy men blessed Jacob, and blessed the children of
#             Israel: for they took the witnesses of Jacob as their
#             witness, and blessed him, and said, Jacob is with his
#             brethren.
#
# 01:021:079 And Jacob's mother, and her name's mother, Jacob and his
#             brethren, was Jezebel's sister: and Jacob was eighteen years
#             old when he began to be born.
#
# 01:021:080 And Jacob had no sons, and his sister Jezebel his wife:
#             for he did not desire to be a wife: for Jacob had no
#             children.
#
# 01:021:081 And he born to them Jacob, and did serve them, and began to
#             serve the children of Israel in the land of their
#             countries, in the time of his birth:
#
# 01:021:082 And Jacob served the children of Israel for three years; and
#             his sister, and her name's mother, did serve them:
#             and she was his mother's daughter: for she had two sons.
#
# 01:021:083 And he had no sons of his, except his two sisters, Jezebel
#             and his brother, who was in his stead.
#
# 01:021:084 But Jacob served him, and he served his children, and
#             served his brethren, and served them: and he served them as
#             his sign, and as a sign to his servants, and as a sign to his
#             servants.
#
# 01:021:085 And he took from the children of Israel the priests, and
#             the Levites, and the chief Levites, and all the elders, and
#             the master of the house, and all the people, and the people's
#             children, and the children's servants, and the people's
#             children's servants, and the children's children's servants, and
#             the people's children's servants, and the people's children's
#             servants;
#
# 01:021:086 And blessed them, and said, All the people which were of them
#             which were born of Jacob, and of the children of Israel, and
#             the children of Israel, and the children of Israel's countries,
#             shall serve
